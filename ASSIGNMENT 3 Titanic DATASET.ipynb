# %%
# Step 1: Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns



# Step 2: Load the dataset
df = pd.read_csv("C:\CC ASSIGNMENT ITRATION 2\ASSIGNMENT 3\Titanic dataset.csv")

# Step 3: Initial overview
print(df.head())
print(df.info())
print(df.describe())
# Out:
#    PassengerId  Survived  Pclass                                  Name  \
# 0            1         1       3                    Allen, Mr. William
# 1            2         0       1              Bonnell, Miss. Elizabeth
# 2            3         1       3           Saundercock, Mr. William H.
# 3            4         1       1           Andersson, Mr. Anders Johan
# 4            5         0       3  Vestrom, Miss. Hulda Amanda Adolfina
#
#       Sex  Age  SibSp  Parch     Ticket   Fare Cabin Embarked
# 0    male   35      0      0     373450   8.05   NaN        S
# 1  female   58      0      0     113781  26.55  C103        C
# 2    male   20      0      0  A/5. 2151   7.25   NaN        S
# 3    male   39      1      5     347082  31.28   NaN        S
# 4  female   14      0      0     350406   7.75   NaN        S
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ...

# %%
print("Missing values before cleaning:\n", df.isnull().sum())
# Out:
# Missing values before cleaning:
#  PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          7
# Embarked       0
# dtype: int64

# %%
# Drop 'Cabin' due to many missing values
df.drop(columns=['Cabin'], inplace=True)

# %%
# Check again
print("Missing values after cleaning:\n", df.isnull().sum())
# Out:
# Missing values after cleaning:
#  PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
survival_by_gender = df.groupby('Sex')['Survived'].mean()
print("\nSurvival Rate by Gender:\n", survival_by_gender)
# Out:
# Survival Rate by Gender:
#  Sex
# female    0.250000
# male      0.666667
# Name: Survived, dtype: float64

# %%
survival_by_class = df.groupby('Pclass')['Survived'].mean()
print("\nSurvival Rate by Passenger Class:\n", survival_by_class)
# Out:
# Survival Rate by Passenger Class:
#  Pclass
# 1    0.666667
# 2    0.500000
# 3    0.400000
# Name: Survived, dtype: float64

# %%
# 6.1 Age Distribution (Histogram)
plt.figure(figsize=(8, 5))
plt.hist(df['Age'], bins=30, color='skyblue', edgecolor='black')
plt.title('Age Distribution of Passengers')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
# 6.2 Survival by Class and Gender (Barplot)
plt.figure(figsize=(8, 5))
sns.barplot(data=df, x='Pclass', y='Survived', hue='Sex')
plt.title('Survival Rate by Class and Gender')
plt.ylabel('Survival Rate')
plt.xlabel('Passenger Class')
plt.show()

# %%
# 6.3 Correlation Heatmap
plt.figure(figsize=(10, 6))
corr = df[['Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare']].corr()
sns.heatmap(corr, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# ummary Insights from Titanic Dataset
# Survival Rate by Gender:
#
# Male survival rate is 66.7%, which is significantly higher than expected.
#
# Female survival rate is only 25%, which is unusually low compared to historical records.
#
#  Insight: This dataset  where males survived more often than females, which is the opposite of the actual Titanic data. It's crucial to double-check the data authenticity or column encoding.
#
# Survival Rate by Passenger Class:
#
# 1st Class: Highest survival rate at 66.7%.
#
# 2nd Class: Moderate survival rate at 50%.
#
# 3rd Class: Lowest survival rate at 40%.
#
#  Insight: Higher-class passengers had a better chance of survival, aligning with expectations that wealthier passengers had more access to lifeboats and early evacuation.
#
# Combined Insight:
#
# Passenger class played a strong role in survival, with 1st class passengers significantly more likely to survive.
#
# Gender trends appear reversed in this dataset, suggesting either data issues or specific characteristics of this sample.
